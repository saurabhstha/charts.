# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import squarify

# %%
#load dataset
df = pd.read_csv('expenditures.txt', sep="\t")

# %%
#view data
df
# Out:
#      year             category  expenditure  sex
# 0    2008                 Food         6443    1
# 1    2008  Alcoholic Beverages          444    1
# 2    2008              Housing        17109    1
# 3    2008              Apparel         1801    1
# 4    2008       Transportation         8604    1
# ..    ...                  ...          ...  ...
# 345  1984            Education          303    1
# 346  1984     Tobacco Products          228    1
# 347  1984        Miscellaneous          451    1
# 348  1984   Cash Contributions          706    1
# 349  1984   Personal Insurance         1897    1
#
# [350 rows x 4 columns]

# %%
# Calculate total expenditure for categories
expen_cat = df.groupby(['category'])['expenditure'].sum().reset_index()


#Create our plot and resize it.
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(14, 8)

# Plot tree map now
squarify.plot(sizes=expen_cat['expenditure'], 
              label=expen_cat['category'], 
              alpha=.8 )
plt.title('Expenditure by Category')
plt.axis('off')
plt.show()

# %%
#create pivot table
df1= df.pivot(index='year', columns='category', values= 'expenditure')
df1
# Out:
# category  Alcoholic Beverages  Apparel  Cash Contributions  Education  \
# year
# 1984                      275     1319                 706        303
# 1985                      306     1420                 805        321
# 1986                      271     1346                 746        314
# 1987                      289     1446                 741        337
# 1988                      269     1489                 693        342
# 1989                      284     1582                 900        367
# 1990                      293     1618                 816        406
# 1991                      297     1735                 950        447
# 1992                      301     1710                 958        426
# 1993                      268     1676                 961        455
# 1994                      278     1644                 960        460
# 1995                      277     1704                 925        471
# ...

# %%
#create stacked area chart using above pivot table

df1.plot.area(figsize = (17,8))
plt.title("Expenditure by year\n", fontsize = 5, loc = 'right')
plt.ylabel("Expenditure", fontsize = 9)
plt.xlabel("Year", fontsize = 9)
plt.show()

# %%
# Calculate total expenditure by year
exp_year = df.groupby(['year'])['expenditure'].sum().reset_index()

# Area Chart
plt.fill_between(exp_year['year'], exp_year['expenditure'])
plt.xlabel('Year')
plt.ylabel('Expenditure')
plt.title('Expenditure by Year')
plt.show()
